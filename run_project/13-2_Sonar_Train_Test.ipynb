# %% [markdown]
# ### 13장 과적합 피하기
#
# #### 2. 과적합 이해하기
# - **```과적합(overfitting)```**
#     : 모델이 학습 데이터셋 안에서는 일정 수준 이상의 예측 정확도,
#     but 새로운 데이터에 적용하면 잘 맞지 않는 것
# - 층이 너무 많거나 변수가 복잡해서 발생
#     or 테스트셋과 학습 셋이 중복될 때 발생
#
#
# #### 3. 학습셋과 데이터셋
# - 과적합 방지 방법 1: 학습셋과 테스트셋을 완전히 구분한 다음 학습과 동시에 테스트를 병행하며 진행
# - 모델: 학습의 결과를 저장한 파일
# - <img src="https://thebook.io/img/080228/166.jpg" width="400" align="left">
#
# #
# #
# #
# ###
# - 과적합 발생 구간: 학습셋 내부의 성공률은 높아져도 테스트셋에서는 효과 X
#     <img src = "https://thebook.io/img/080228/167_1.jpg" width="300" align="left">
#
# #
# #
# #
# ###

# %% [markdown]
# 초음파 광물 예측하기: 학습셋과 테스트셋 구분

# %%
from keras.models import Sequential
from keras.layers.core import Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
# seed 값 설정
seed = 0
np.random.seed(seed)
tf.random.set_seed(3)
df = pd.read_csv('../dataset/sonar.csv', header=None)

# %%
dataset = df.values
X = dataset[:, 0:60]
Y_obj = dataset[:, 60]

e = LabelEncoder()
e.fit(Y_obj)
Y = e.transform(Y_obj)

# 학습 셋과 테스트셋의 구분
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=seed)

# %%
# 모델 설정
model = Sequential()
model.add(Dense(24, input_dim=60, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(loss='mean_squared_error',
             optimizer='adam',
             metrics=['accuracy'])

# %%
# 모델 실행
model.fit(X_train, Y_train, epochs=130, batch_size=5)

# 테스트셋에 모델 적용
print("\n Test Accuracy: %.4f" % (model.evaluate(X_test, Y_test)[1]))
# Out:
# Epoch 1/130
# 145/145 [==============================] - 0s 249us/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 2/130
# 145/145 [==============================] - 0s 222us/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 3/130
# 145/145 [==============================] - 0s 219us/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 4/130
# 145/145 [==============================] - 0s 235us/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 5/130
# 145/145 [==============================] - 0s 219us/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 6/130
# 145/145 [==============================] - 0s 312us/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 7/130
# 145/145 [==============================] - 0s 201us/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 8/130
# 145/145 [==============================] - 0s 210us/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 9/130
# 145/145 [==============================] - 0s 234us/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 10/130
# ...
